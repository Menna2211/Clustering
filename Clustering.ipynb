# %% [markdown]
# # **UnSupervised Learning**
# We 've went to learn so far many applications in Supervised learning whether Classifiers or Regressors now its your time to meet a new appearance for Machine Learning which is Unsupervised Learning

# %% [markdown]
# # Clustering

# %% [markdown]
# # K-means

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.cluster import KMeans

# %%
a= np.array([10,11,12,200,220,350,360])
a=a.reshape(-1,1)

# %%
import seaborn as sns
g= sns.heatmap(a, annot= True)

# %%
clust=KMeans(n_clusters=3, random_state=3)
clust.fit(a)
# Out:
# KMeans(n_clusters=3, random_state=3)

# %%
preds=clust.predict(a)
preds
# Out:
# array([0, 0, 0, 1, 1, 2, 2], dtype=int32)

# %% [markdown]
# As We see, We could easily build a K mean Model
# Now  Let's Go for a real World Data Set and see how can this be Challenging.

# %%
from google.colab import drive
drive.mount('/content/drive/')
import os
os.chdir('/content/drive/MyDrive/E2Edata')  # Fix This if your file is in a Certain Directory in Your Drive
# Out:
# Mounted at /content/drive/

# %%
# read our dataset
dataset = pd.read_csv('Mall_Customers.csv')
dataset
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
sns.pairplot(dataset)

# %%
features = dataset.iloc[:, 1:].values
# Pre Processing Phase
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
features[:,0] = encoder.fit_transform(features[:,0])

pd.DataFrame(features)
# Out:
#      0   1    2   3
# 0    1  19   15  39
# 1    1  21   15  81
# 2    0  20   16   6
# 3    0  23   16  77
# 4    0  31   17  40
# ..  ..  ..  ...  ..
# 195  0  35  120  79
# 196  0  45  126  28
# 197  1  32  126  74
# 198  1  32  137  18
# 199  1  30  137  83
#
# [200 rows x 4 columns]

# %%
features
# Out:
# array([[1, 19, 15, 39],
#        [1, 21, 15, 81],
#        [0, 20, 16, 6],
#        [0, 23, 16, 77],
#        [0, 31, 17, 40],
#        [0, 22, 17, 76],
#        [0, 35, 18, 6],
#        [0, 23, 18, 94],
#        [1, 64, 19, 3],
#        [0, 30, 19, 72],
#        [1, 67, 19, 14],
#        [0, 35, 19, 99],
#        [0, 58, 20, 15],
#        [0, 24, 20, 77],
#        [1, 37, 20, 13],
#        [1, 22, 20, 79],
#        [0, 35, 21, 35],
#        [1, 20, 21, 66],
#        [1, 52, 23, 29],
#        [0, 35, 23, 98],
#        [1, 35, 24, 35],
#        [1, 25, 24, 73],
#        [0, 46, 25, 5],
#        [1, 31, 25, 73],
#        [0, 54, 28, 14],
#        [1, 29, 28, 82],
#        [0, 45, 28, 32],
#        [1, 35, 28, 61],
#        [0, 40, 29, 31],
#        [0, 23, 29, 87],
#        [1, 60, 30, 4],
#        [0, 21, 30, 73],
#        [1, 53, 33, 4],
#        [1, 18, 33, 92],
#        [0, 49, 33, 14],
#        [0, 21, 33, 81],
#        [0, 42, 34, 17],
#        [0, 30, 34, 73],
# ...

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters = 5, random_state = 0)
kmeans_predictions = kmeans.fit_predict(features)
kmeans_predictions
# Out:
# array([0, 4, 0, 4, 0, 4, 0, 4, 0, 4, 0, 4, 0, 4, 0, 4, 0, 4, 0, 4, 0, 4,
#        0, 4, 0, 4, 0, 4, 0, 4, 0, 4, 0, 4, 0, 4, 0, 4, 0, 4, 0, 4, 0, 4,
#        0, 4, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 3, 1, 2, 1, 3, 1, 3, 1,
#        3, 1, 3, 1, 3, 1, 3, 1, 3, 1, 2, 1, 3, 1, 3, 1, 3, 1, 3, 1, 3, 1,
#        3, 1, 3, 1, 3, 1, 3, 1, 3, 1, 3, 1, 3, 1, 3, 1, 3, 1, 3, 1, 3, 1,
#        3, 1, 3, 1, 3, 1, 3, 1, 3, 1, 3, 1, 3, 1, 3, 1, 3, 1, 3, 1, 3, 1,
#        3, 1], dtype=int32)

# %%
# Visualising the clusters
plt.scatter(features[kmeans_predictions == 0, 2], features[kmeans_predictions == 0, -1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(features[kmeans_predictions == 1, 2], features[kmeans_predictions == 1, -1], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(features[kmeans_predictions == 2, 2], features[kmeans_predictions == 2, -1], s = 100, c = 'green', label = 'Cluster 3')
plt.scatter(features[kmeans_predictions == 3, 2], features[kmeans_predictions == 3, -1], s = 100, c = 'cyan', label = 'Cluster 4')
plt.scatter(features[kmeans_predictions == 4, 2], features[kmeans_predictions == 4, -1], s = 100, c = 'magenta', label = 'Cluster 5')
plt.scatter(kmeans.cluster_centers_[:, 2], kmeans.cluster_centers_[:, -1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clusters of customers')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()

# %%
# Visualising the clusters
plt.scatter(features[kmeans_predictions == 0, 1], features[kmeans_predictions == 0, -1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(features[kmeans_predictions == 1, 1], features[kmeans_predictions == 1, -1], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(features[kmeans_predictions == 2, 1], features[kmeans_predictions == 2, -1], s = 100, c = 'green', label = 'Cluster 3')
plt.scatter(features[kmeans_predictions == 3, 1], features[kmeans_predictions == 3, -1], s = 100, c = 'cyan', label = 'Cluster 4')
plt.scatter(features[kmeans_predictions == 4, 1], features[kmeans_predictions == 4, -1], s = 100, c = 'magenta', label = 'Cluster 5')
#plt.scatter(kmeans.cluster_centers_[:, 2], kmeans.cluster_centers_[:, -1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clusters of customers')
plt.xlabel('Age ')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()

# %%
# Visualising the clusters
plt.scatter(features[kmeans_predictions == 0, 2], features[kmeans_predictions == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(features[kmeans_predictions == 1, 2], features[kmeans_predictions == 1, 1], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(features[kmeans_predictions == 2, 2], features[kmeans_predictions == 2, 1], s = 100, c = 'green', label = 'Cluster 3')
plt.scatter(features[kmeans_predictions == 3, 2], features[kmeans_predictions == 3, 1], s = 100, c = 'cyan', label = 'Cluster 4')
plt.scatter(features[kmeans_predictions == 4, 2], features[kmeans_predictions == 4, 1], s = 100, c = 'magenta', label = 'Cluster 5')
# plt.scatter(kmeans.cluster_centers_[:, 2], kmeans.cluster_centers_[:, -1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clusters of customers')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Age')
plt.legend()
plt.show()

# %%
# Visualising the clusters
plt.scatter(features[kmeans_predictions == 0, 2], features[kmeans_predictions == 0, 0], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(features[kmeans_predictions == 1, 2], features[kmeans_predictions == 1, 0], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(features[kmeans_predictions == 2, 2], features[kmeans_predictions == 2, 0], s = 100, c = 'green', label = 'Cluster 3')
plt.scatter(features[kmeans_predictions == 3, 2], features[kmeans_predictions == 3, 0], s = 100, c = 'cyan', label = 'Cluster 4')
plt.scatter(features[kmeans_predictions == 4, 2], features[kmeans_predictions == 4, 0], s = 100, c = 'magenta', label = 'Cluster 5')
# plt.scatter(kmeans.cluster_centers_[:, 2], kmeans.cluster_centers_[:, -1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clusters of customers')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Gender')
plt.legend()
plt.show()

# %%
from sklearn.mixture import GaussianMixture
gm = GaussianMixture(n_components=5,random_state=0)
gm.fit(features)
gm_predictions = gm.predict(features)

# %%
# Visualising the clusters
plt.scatter(features[gm_predictions == 0, 2], features[gm_predictions == 0, -1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(features[gm_predictions == 1, 2], features[gm_predictions == 1, -1], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(features[gm_predictions == 2, 2], features[gm_predictions == 2, -1], s = 100, c = 'green', label = 'Cluster 3')
plt.scatter(features[gm_predictions == 3, 2], features[gm_predictions == 3, -1], s = 100, c = 'cyan', label = 'Cluster 4')
plt.scatter(features[gm_predictions == 4, 2], features[gm_predictions == 4, -1], s = 100, c = 'magenta', label = 'Cluster 5')
plt.scatter(kmeans.cluster_centers_[:, 2], kmeans.cluster_centers_[:, -1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clusters of customers')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()

# %%
# Visualising the clusters
plt.scatter(features[gm_predictions == 0, 1], features[gm_predictions == 0, -1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(features[gm_predictions == 1, 1], features[gm_predictions == 1, -1], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(features[gm_predictions == 2, 1], features[gm_predictions == 2, -1], s = 100, c = 'green', label = 'Cluster 3')
plt.scatter(features[gm_predictions == 3, 1], features[gm_predictions == 3, -1], s = 100, c = 'cyan', label = 'Cluster 4')
plt.scatter(features[gm_predictions == 4, 1], features[gm_predictions == 4, -1], s = 100, c = 'magenta', label = 'Cluster 5')
#plt.scatter(kmeans.cluster_centers_[:, 2], kmeans.cluster_centers_[:, -1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clusters of customers')
plt.xlabel('Age')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()

# %%
# Visualising the clusters
plt.scatter(features[gm_predictions == 0, 2], features[gm_predictions == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(features[gm_predictions == 1, 2], features[gm_predictions == 1, 1], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(features[gm_predictions == 2, 2], features[gm_predictions == 2, 1], s = 100, c = 'green', label = 'Cluster 3')
plt.scatter(features[gm_predictions == 3, 2], features[gm_predictions == 3, 1], s = 100, c = 'cyan', label = 'Cluster 4')
plt.scatter(features[gm_predictions == 4, 2], features[gm_predictions == 4, 1], s = 100, c = 'magenta', label = 'Cluster 5')
#plt.scatter(kmeans.cluster_centers_[:, 2], kmeans.cluster_centers_[:, -1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clusters of customers')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Age')
plt.legend()
plt.show()

# %% [markdown]
# **NOTE:** Always whenever you face something in Syntax that you can't understand try to break it like this

# %% [markdown]
# Cluster ==1 , Feature 1 =Age

# %%
features[kmeans_predictions == 0, 1]
# Out:
# array([19, 20, 31, 35, 64, 67, 58, 37, 35, 52, 35, 46, 54, 45, 40, 60, 53,
#        49, 42, 36, 65, 48, 49], dtype=object)

# %% [markdown]
# Cluster ==1

# %%
kmeans_predictions == 0
# Out:
# array([ True, False,  True, False,  True, False,  True, False,  True,
#        False,  True, False,  True, False,  True, False,  True, False,
#         True, False,  True, False,  True, False,  True, False,  True,
#        False,  True, False,  True, False,  True, False,  True, False,
#         True, False,  True, False,  True, False,  True, False,  True,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
# ...

# %%
features[kmeans_predictions == 0, -1]

# %%
wcss = []
for i in range(1, 20):
    kmeans = KMeans(n_clusters = i, random_state = 0)
    kmeans.fit(features)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 20), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# build a 5 clusters algorithm
kmeans = KMeans(n_clusters = 5, random_state = 0)
kmeans_predictions5 = kmeans.fit_predict(features)

# visualizing it
# Visualising the clusters
plt.scatter(features[kmeans_predictions5 == 0, 2], features[kmeans_predictions5 == 0, -1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(features[kmeans_predictions5 == 1, 2], features[kmeans_predictions5 == 1, -1], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(features[kmeans_predictions5 == 2, 2], features[kmeans_predictions5 == 2, -1], s = 100, c = 'green', label = 'Cluster 3')
plt.scatter(features[kmeans_predictions5 == 3, 2], features[kmeans_predictions5 == 3, -1], s = 100, c = 'cyan', label = 'Cluster 4')
plt.scatter(features[kmeans_predictions5 == 4, 2], features[kmeans_predictions5 == 4, -1], s = 100, c = 'magenta', label = 'Cluster 5')
plt.scatter(kmeans.cluster_centers_[:, 2], kmeans.cluster_centers_[:, -1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clusters of customers')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()

# %%
kmeans.cluster_centers_

# %%
# build a 5 clusters algorithm
kmeans5 = KMeans(n_clusters = 5, random_state = 0)
kmeans_predictions5 = kmeans5.fit_predict(features)
# build a 5 clusters algorithm
kmeans6 = KMeans(n_clusters = 6, random_state = 0)
kmeans_predictions6 = kmeans6.fit_predict(features)
# visualizing it
# Visualising the clusters
fig, axs = plt.subplots(2)
axs[0].scatter(features[kmeans_predictions5 == 0, 2], features[kmeans_predictions5 == 0, -1], s = 100, c = 'red', label = 'Cluster 1')
axs[0].scatter(features[kmeans_predictions5 == 1, 2], features[kmeans_predictions5 == 1, -1], s = 100, c = 'blue', label = 'Cluster 2')
axs[0].scatter(features[kmeans_predictions5 == 2, 2], features[kmeans_predictions5 == 2, -1], s = 100, c = 'green', label = 'Cluster 3')
axs[0].scatter(features[kmeans_predictions5 == 3, 2], features[kmeans_predictions5 == 3, -1], s = 100, c = 'cyan', label = 'Cluster 4')
axs[0].scatter(features[kmeans_predictions5 == 4, 2], features[kmeans_predictions5 == 4, -1], s = 100, c = 'magenta', label = 'Cluster 5')
axs[0].scatter(kmeans5.cluster_centers_[:, 2], kmeans5.cluster_centers_[:, -1], s = 300, c = 'yellow', label = 'Centroids')
axs[0].set_xlabel('Annual Income (k$)')
axs[0].set_ylabel('Spending Score (1-100)')

axs[1].scatter(features[kmeans_predictions6 == 0, 2], features[kmeans_predictions6 == 0, -1], s = 100, c = 'red', label = 'Cluster 1')
axs[1].scatter(features[kmeans_predictions6 == 1, 2], features[kmeans_predictions6 == 1, -1], s = 100, c = 'blue', label = 'Cluster 2')
axs[1].scatter(features[kmeans_predictions6 == 2, 2], features[kmeans_predictions6 == 2, -1], s = 100, c = 'green', label = 'Cluster 3')
axs[1].scatter(features[kmeans_predictions6 == 3, 2], features[kmeans_predictions6 == 3, -1], s = 100, c = 'cyan', label = 'Cluster 4')
axs[1].scatter(features[kmeans_predictions6 == 4, 2], features[kmeans_predictions6 == 4, -1], s = 100, c = 'magenta', label = 'Cluster 5')
axs[1].scatter(features[kmeans_predictions6 == 5, 2], features[kmeans_predictions6 == 5, -1], s = 100, c = 'black', label = 'Cluster 6')
axs[1].scatter(kmeans6.cluster_centers_[:, 2], kmeans6.cluster_centers_[:, -1], s = 300, c = 'yellow', label = 'Centroids')
fig.suptitle('Clusters of customers')
axs[1].set_xlabel('Annual Income (k$)')
axs[1].set_ylabel('Spending Score (1-100)')
# Out:
# Text(0, 0.5, 'Spending Score (1-100)')

# %%
# build a 5 clusters algorithm
kmeans5 = KMeans(n_clusters = 5, random_state = 0)
kmeans_predictions5 = kmeans5.fit_predict(features)
# build a 5 clusters algorithm
kmeans6 = KMeans(n_clusters = 6, random_state = 0)
kmeans_predictions6 = kmeans6.fit_predict(features)
# visualizing it
# Visualising the clusters
fig, axs = plt.subplots(2)
axs[0].scatter(features[kmeans_predictions5 == 0, 1], features[kmeans_predictions5 == 0, -1], s = 100, c = 'red', label = 'Cluster 1')
axs[0].scatter(features[kmeans_predictions5 == 1, 1], features[kmeans_predictions5 == 1, -1], s = 100, c = 'blue', label = 'Cluster 2')
axs[0].scatter(features[kmeans_predictions5 == 2, 1], features[kmeans_predictions5 == 2, -1], s = 100, c = 'green', label = 'Cluster 3')
axs[0].scatter(features[kmeans_predictions5 == 3, 1], features[kmeans_predictions5 == 3, -1], s = 100, c = 'cyan', label = 'Cluster 4')
axs[0].scatter(features[kmeans_predictions5 == 4, 1], features[kmeans_predictions5 == 4, -1], s = 100, c = 'magenta', label = 'Cluster 5')
axs[0].set_xlabel('Age')
axs[0].set_ylabel('Spending Score (1-100)')

axs[1].scatter(features[kmeans_predictions6 == 0, 1], features[kmeans_predictions6 == 0, -1], s = 100, c = 'red', label = 'Cluster 1')
axs[1].scatter(features[kmeans_predictions6 == 1, 1], features[kmeans_predictions6 == 1, -1], s = 100, c = 'blue', label = 'Cluster 2')
axs[1].scatter(features[kmeans_predictions6 == 2, 1], features[kmeans_predictions6 == 2, -1], s = 100, c = 'green', label = 'Cluster 3')
axs[1].scatter(features[kmeans_predictions6 == 3, 1], features[kmeans_predictions6 == 3, -1], s = 100, c = 'cyan', label = 'Cluster 4')
axs[1].scatter(features[kmeans_predictions6 == 4, 1], features[kmeans_predictions6 == 4, -1], s = 100, c = 'magenta', label = 'Cluster 5')
axs[1].scatter(features[kmeans_predictions6 == 5, 1], features[kmeans_predictions6 == 5, -1], s = 100, c = 'black', label = 'Cluster 6')
fig.suptitle('Clusters of customers')
axs[1].set_xlabel('Age (k$)')
axs[1].set_ylabel('Spending Score (1-100)')
# Out:
# Text(0, 0.5, 'Spending Score (1-100)')

# %%
# build a 5 clusters algorithm
kmeans5 = KMeans(n_clusters = 5, random_state = 0)
kmeans_predictions5 = kmeans5.fit_predict(features)
# build a 5 clusters algorithm
kmeans6 = KMeans(n_clusters = 6, random_state = 0)
kmeans_predictions6 = kmeans6.fit_predict(features)
# visualizing it
# Visualising the clusters
fig, axs = plt.subplots(2)
axs[0].scatter(features[kmeans_predictions5 == 0, 2], features[kmeans_predictions5 == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
axs[0].scatter(features[kmeans_predictions5 == 1, 2], features[kmeans_predictions5 == 1, 1], s = 100, c = 'blue', label = 'Cluster 2')
axs[0].scatter(features[kmeans_predictions5 == 2, 2], features[kmeans_predictions5 == 2, 1], s = 100, c = 'green', label = 'Cluster 3')
axs[0].scatter(features[kmeans_predictions5 == 3, 2], features[kmeans_predictions5 == 3, 1], s = 100, c = 'cyan', label = 'Cluster 4')
axs[0].scatter(features[kmeans_predictions5 == 4, 2], features[kmeans_predictions5 == 4, 1], s = 100, c = 'magenta', label = 'Cluster 5')
axs[0].set_xlabel('Annual Income (k$)')
axs[0].set_ylabel('Age')

axs[1].scatter(features[kmeans_predictions6 == 0, 2], features[kmeans_predictions6 == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
axs[1].scatter(features[kmeans_predictions6 == 1, 2], features[kmeans_predictions6 == 1, 1], s = 100, c = 'blue', label = 'Cluster 2')
axs[1].scatter(features[kmeans_predictions6 == 2, 2], features[kmeans_predictions6 == 2, 1], s = 100, c = 'green', label = 'Cluster 3')
axs[1].scatter(features[kmeans_predictions6 == 3, 2], features[kmeans_predictions6 == 3, 1], s = 100, c = 'cyan', label = 'Cluster 4')
axs[1].scatter(features[kmeans_predictions6 == 4, 2], features[kmeans_predictions6 == 4, 1], s = 100, c = 'magenta', label = 'Cluster 5')
axs[1].scatter(features[kmeans_predictions6 == 5, 2], features[kmeans_predictions6 == 5, 1], s = 100, c = 'black', label = 'Cluster 6')

fig.suptitle('Clusters of customers')
axs[1].set_xlabel('Annual Income (k$)')
axs[1].set_ylabel('Age')
# Out:
# Text(0, 0.5, 'Age')

# %%
# build a 5 clusters algorithm
gm5 = GaussianMixture(n_components=5,random_state=0)
gm5.fit(features)
gm_predictions5 = gm5.predict(features)
# build a 6 clusters algorithm
gm6 = GaussianMixture(n_components=6,random_state=0)
gm6.fit(features)
gm_predictions6 = gm6.predict(features)


# visualizing it
# Visualising the clusters
fig, axs = plt.subplots(2)
axs[0].scatter(features[gm_predictions5 == 0, 2], features[gm_predictions5 == 0, -1], s = 100, c = 'red', label = 'Cluster 1')
axs[0].scatter(features[gm_predictions5 == 1, 2], features[gm_predictions5 == 1, -1], s = 100, c = 'blue', label = 'Cluster 2')
axs[0].scatter(features[gm_predictions5 == 2, 2], features[gm_predictions5 == 2, -1], s = 100, c = 'green', label = 'Cluster 3')
axs[0].scatter(features[gm_predictions5 == 3, 2], features[gm_predictions5 == 3, -1], s = 100, c = 'cyan', label = 'Cluster 4')
axs[0].scatter(features[gm_predictions5 == 4, 2], features[gm_predictions5 == 4, -1], s = 100, c = 'magenta', label = 'Cluster 5')
axs[0].scatter(kmeans5.cluster_centers_[:, 2], kmeans5.cluster_centers_[:, -1], s = 300, c = 'yellow', label = 'Centroids')
axs[0].set_xlabel('Annual Income (k$)')
axs[0].set_ylabel('Spending Score (1-100)')

axs[1].scatter(features[gm_predictions6 == 0, 2], features[gm_predictions6 == 0, -1], s = 100, c = 'red', label = 'Cluster 1')
axs[1].scatter(features[gm_predictions6 == 1, 2], features[gm_predictions6 == 1, -1], s = 100, c = 'blue', label = 'Cluster 2')
axs[1].scatter(features[gm_predictions6 == 2, 2], features[gm_predictions6 == 2, -1], s = 100, c = 'green', label = 'Cluster 3')
axs[1].scatter(features[gm_predictions6 == 3, 2], features[gm_predictions6 == 3, -1], s = 100, c = 'cyan', label = 'Cluster 4')
axs[1].scatter(features[gm_predictions6 == 4, 2], features[gm_predictions6 == 4, -1], s = 100, c = 'magenta', label = 'Cluster 5')
axs[1].scatter(features[gm_predictions6 == 5, 2], features[gm_predictions6 == 5, -1], s = 100, c = 'black', label = 'Cluster 6')
axs[1].scatter(kmeans6.cluster_centers_[:, 2], kmeans6.cluster_centers_[:, -1], s = 300, c = 'yellow', label = 'Centroids')
fig.suptitle('Clusters of customers')
axs[1].set_xlabel('Annual Income (k$)')
axs[1].set_ylabel('Spending Score (1-100)')
# Out:
# Text(0, 0.5, 'Spending Score (1-100)')

# %%
# build a 5 clusters algorithm
gm5 = GaussianMixture(n_components=5,random_state=0)
gm5.fit(features)
gm_predictions5 = gm5.predict(features)
# build a 6 clusters algorithm
gm6 = GaussianMixture(n_components=6,random_state=0)
gm6.fit(features)
gm_predictions6 = gm6.predict(features)


# visualizing it
# Visualising the clusters
fig, axs = plt.subplots(2)
axs[0].scatter(features[gm_predictions5 == 0, 1], features[gm_predictions5 == 0, -1], s = 100, c = 'red', label = 'Cluster 1')
axs[0].scatter(features[gm_predictions5 == 1, 1], features[gm_predictions5 == 1, -1], s = 100, c = 'blue', label = 'Cluster 2')
axs[0].scatter(features[gm_predictions5 == 2, 1], features[gm_predictions5 == 2, -1], s = 100, c = 'green', label = 'Cluster 3')
axs[0].scatter(features[gm_predictions5 == 3, 1], features[gm_predictions5 == 3, -1], s = 100, c = 'cyan', label = 'Cluster 4')
axs[0].scatter(features[gm_predictions5 == 4, 1], features[gm_predictions5 == 4, -1], s = 100, c = 'magenta', label = 'Cluster 5')
#axs[0].scatter(kmeans5.cluster_centers_[:, 2], kmeans5.cluster_centers_[:, -1], s = 300, c = 'yellow', label = 'Centroids')
axs[0].set_xlabel('Age')
axs[0].set_ylabel('Spending Score (1-100)')

axs[1].scatter(features[gm_predictions6 == 0, 1], features[gm_predictions6 == 0, -1], s = 100, c = 'red', label = 'Cluster 1')
axs[1].scatter(features[gm_predictions6 == 1, 1], features[gm_predictions6 == 1, -1], s = 100, c = 'blue', label = 'Cluster 2')
axs[1].scatter(features[gm_predictions6 == 2, 1], features[gm_predictions6 == 2, -1], s = 100, c = 'green', label = 'Cluster 3')
axs[1].scatter(features[gm_predictions6 == 3, 1], features[gm_predictions6 == 3, -1], s = 100, c = 'cyan', label = 'Cluster 4')
axs[1].scatter(features[gm_predictions6 == 4, 1], features[gm_predictions6 == 4, -1], s = 100, c = 'magenta', label = 'Cluster 5')
axs[1].scatter(features[gm_predictions6 == 5, 1], features[gm_predictions6 == 5, -1], s = 100, c = 'black', label = 'Cluster 6')
#axs[1].scatter(kmeans6.cluster_centers_[:, 2], kmeans6.cluster_centers_[:, -1], s = 300, c = 'yellow', label = 'Centroids')
fig.suptitle('Clusters of customers')
axs[1].set_xlabel('Age')
axs[1].set_ylabel('Spending Score (1-100)')
# Out:
# Text(0, 0.5, 'Spending Score (1-100)')

# %%
# build a 5 clusters algorithm
gm5 = GaussianMixture(n_components=5,random_state=0)
gm5.fit(features)
gm_predictions5 = gm5.predict(features)
# build a 6 clusters algorithm
gm6 = GaussianMixture(n_components=6,random_state=0)
gm6.fit(features)
gm_predictions6 = gm6.predict(features)


# visualizing it
# Visualising the clusters
fig, axs = plt.subplots(2)
axs[0].scatter(features[gm_predictions5 == 0, 1], features[gm_predictions5 == 0, 2], s = 100, c = 'red', label = 'Cluster 1')
axs[0].scatter(features[gm_predictions5 == 1, 1], features[gm_predictions5 == 1, 2], s = 100, c = 'blue', label = 'Cluster 2')
axs[0].scatter(features[gm_predictions5 == 2, 1], features[gm_predictions5 == 2, 2], s = 100, c = 'green', label = 'Cluster 3')
axs[0].scatter(features[gm_predictions5 == 3, 1], features[gm_predictions5 == 3, 2], s = 100, c = 'cyan', label = 'Cluster 4')
axs[0].scatter(features[gm_predictions5 == 4, 1], features[gm_predictions5 == 4, 2], s = 100, c = 'magenta', label = 'Cluster 5')
#axs[0].scatter(kmeans5.cluster_centers_[:, 2], kmeans5.cluster_centers_[:, -1], s = 300, c = 'yellow', label = 'Centroids')
axs[0].set_xlabel('Age')
axs[0].set_ylabel('Annual Income (k$)')

axs[1].scatter(features[gm_predictions6 == 0, 1], features[gm_predictions6 == 0, 2], s = 100, c = 'red', label = 'Cluster 1')
axs[1].scatter(features[gm_predictions6 == 1, 1], features[gm_predictions6 == 1, 2], s = 100, c = 'blue', label = 'Cluster 2')
axs[1].scatter(features[gm_predictions6 == 2, 1], features[gm_predictions6 == 2, 2], s = 100, c = 'green', label = 'Cluster 3')
axs[1].scatter(features[gm_predictions6 == 3, 1], features[gm_predictions6 == 3, 2], s = 100, c = 'cyan', label = 'Cluster 4')
axs[1].scatter(features[gm_predictions6 == 4, 1], features[gm_predictions6 == 4, 2], s = 100, c = 'magenta', label = 'Cluster 5')
axs[1].scatter(features[gm_predictions6 == 5, 1], features[gm_predictions6 == 5, 2], s = 100, c = 'black', label = 'Cluster 6')
#axs[1].scatter(kmeans6.cluster_centers_[:, 2], kmeans6.cluster_centers_[:, -1], s = 300, c = 'yellow', label = 'Centroids')
fig.suptitle('Clusters of customers')
axs[1].set_xlabel('Age')
axs[1].set_ylabel('Annual Income (k$)')
# Out:
# Text(0, 0.5, 'Annual Income (k$)')

# %% [markdown]
# # Agglomerative Heirarichal Clustering

# %%
import scipy.cluster.hierarchy as sch
dendrogram = sch.dendrogram(sch.linkage(features, method = 'ward'))
plt.title('Dendrogram')
plt.xlabel('Customers')
plt.ylabel('Euclidean distances')
plt.show()

# %%
# Fitting Hierarchical Clustering to the dataset
from sklearn.cluster import AgglomerativeClustering
hc = AgglomerativeClustering(n_clusters = 5, affinity = 'euclidean', linkage = 'ward')
y_hc = hc.fit_predict(features)

# %%
plt.scatter(features[y_hc == 0, 2], features[y_hc == 0, -1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(features[y_hc == 1, 2], features[y_hc == 1, -1], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(features[y_hc == 2, 2], features[y_hc == 2, -1], s = 100, c = 'green', label = 'Cluster 3')
plt.scatter(features[y_hc == 3, 2], features[y_hc == 3, -1], s = 100, c = 'cyan', label = 'Cluster 4')
plt.scatter(features[y_hc == 4, 2], features[y_hc == 4, -1], s = 100, c = 'magenta', label = 'Cluster 5')
plt.title('Clusters of customers')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()

# %% [markdown]
# # Do you remember Heatmaps ?

# %%
# Let's Create Random Data
import seaborn as sns
g=np.random.random([20,10])
g
# Out:
# array([[9.17595878e-01, 2.96977597e-01, 2.04203017e-01, 1.27655587e-02,
#         1.18411815e-01, 1.64748824e-01, 8.17594942e-01, 7.47253307e-02,
#         2.04484926e-01, 8.54998584e-01],
#        [1.23252263e-01, 7.96827395e-02, 2.38752931e-01, 9.92704847e-01,
#         1.29915577e-01, 4.19121968e-01, 6.64101403e-02, 4.08603288e-01,
#         9.05013872e-01, 4.90695321e-01],
#        [4.28475587e-01, 8.10930642e-01, 7.68986859e-01, 4.55457668e-01,
#         6.79651222e-01, 9.70802595e-01, 7.90525205e-01, 7.92060974e-01,
#         9.06999252e-01, 4.50209243e-01],
#        [5.73321265e-01, 6.56941578e-02, 2.58486956e-02, 7.12453721e-01,
#         1.58750014e-01, 1.10516517e-01, 5.17942295e-02, 1.40576917e-01,
#         5.54559763e-01, 7.64053596e-01],
#        [9.63080556e-01, 9.80025410e-01, 3.38046626e-02, 6.76857710e-01,
#         9.19983758e-01, 1.35909982e-01, 7.29665025e-01, 6.18099982e-01,
#         2.96667855e-01, 8.45251396e-01],
# ...

# %%
pd.DataFrame(g)
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.917596  0.296978  0.204203  0.012766  0.118412  0.164749  0.817595
# 1   0.123252  0.079683  0.238753  0.992705  0.129916  0.419122  0.066410
# 2   0.428476  0.810931  0.768987  0.455458  0.679651  0.970803  0.790525
# 3   0.573321  0.065694  0.025849  0.712454  0.158750  0.110517  0.051794
# 4   0.963081  0.980025  0.033805  0.676858  0.919984  0.135910  0.729665
# 5   0.145455  0.476706  0.686303  0.511323  0.871968  0.067818  0.936260
# 6   0.968201  0.667666  0.925294  0.373684  0.499605  0.079019  0.388826
# 7   0.373775  0.666711  0.090070  0.558357  0.179186  0.285140  0.661627
# 8   0.358766  0.000677  0.560422  0.454402  0.688485  0.172038  0.373506
# 9   0.539762  0.366828  0.292593  0.101464  0.908647  0.169055  0.705612
# 10  0.297178  0.316751  0.970688  0.549729  0.375523  0.841947  0.626068
# 11  0.576632  0.554747  0.139533  0.066443  0.128414  0.812487  0.688982
# ...

# %%
sns.heatmap(g)

# %%
b=sns.load_dataset('iris')
b
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
k=b.pop('species')
k
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %%
sns.heatmap(b)

# %%
iris = sns.load_dataset("iris")
species = iris.pop("species")
g = sns.clustermap(iris,metric='euclidean')

# %% [markdown]
# ![alt text](https://dataaspirant.com/wp-content/uploads/2015/04/cover_post_final.png)

# %%
g = sns.clustermap(iris,metric='cosine')

# %% [markdown]
# **Please** visit this [Link](https://seaborn.pydata.org/generated/seaborn.clustermap.html)

# %% [markdown]
# # PCA

# %%
from sklearn.decomposition import PCA
iris

# %%
df = pd.read_csv('Iris.csv')

# %%
df.columns

# %%
#df = df.drop('Species',axis=1)
df = df.drop('Id',axis=1)

# %%
sns.pairplot(df,hue='Species')
#Task -> colors

# %%
pca = PCA(n_components=4)
pca.fit(iris.values)
feats = pca.transform(iris.values)

# %%
0.92461872+ 0.05306648+ 0.01710261+ 0.00521218

# %%
pca.explained_variance_ratio_

# %%
pca1 = PCA(n_components=2)
pca1.fit(iris.values)
feats = pca1.transform(iris.values)
pca1.explained_variance_ratio_

# %%
0.92461872 + 0.05306648

# %%
pca1

# %%
from sklearn import datasets
from sklearn.preprocessing import scale

# load iris dataset
iris = datasets.load_iris()
loadings = pd.DataFrame(pca.components_.T, columns=['PC1', 'PC2','PC3','PC4'], index=iris.feature_names)
loadings

# %%
pca.components_  #  We use  .T   to Transpose our Pcs  to be Columns instead of being Rows

# %%
import plotly.express as px

df = px.data.iris()
features = ["sepal_width", "sepal_length", "petal_width", "petal_length"]

fig = px.scatter_matrix(
    df,
    dimensions=features,
    color="species"
)
fig.update_traces(diagonal_visible=False)
fig.show()

# %%
features = ["sepal_width", "sepal_length", "petal_width", "petal_length"]

pca = PCA()
components = pca.fit_transform(df[features])
labels = {
    str(i): f"PC {i+1} ({var:.1f}%)"
    for i, var in enumerate(pca.explained_variance_ratio_ * 100)
}

fig = px.scatter_matrix(
    components,
    labels=labels,
    dimensions=range(4),
    color=df["species"]
)
fig.update_traces(diagonal_visible=False)
fig.show()

# %%
#PCA -> train data

# %%
# PCA -> test data

# %%
#PCA --XX label

# %%
#PCA with clustering -> no label aslun
